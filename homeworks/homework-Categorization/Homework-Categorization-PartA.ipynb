# %% [markdown]
# # Homework - Categorization and Model Comparison Part A (70/105 points)

# %% [markdown]
# PSY/COS 360, Computational Models of Cognition, Fall 2026.
#
# Credit for first version and for the categorization data: Prof. Todd Gureckis at New York University.

# %% [markdown]
# <div style="background-color: #eef2f6; color: #1f2933; border-left: 4px solid #7b8a97; padding: 12px 16px; border-radius: 4px;">
#
# <p style="margin-top: 0;">Parts of your code are checked by an automated grader. For the grader to work, please keep the following in mind as you complete the assignment:</p>
#
# <ul style="margin-bottom: 0;">
# <li><b>Do not rename this notebook file or any of the starter functions we provide.</b> The grader looks for them by name, so a renamed file or function will fail even if the code is correct.</li>
# <li><b>Make sure the notebook runs from top to bottom without errors.</b> Before submitting, choose <code>Restart</code>, <code>Clear All Outputs</code>, and then <code>Run All</code> from the notebook menu. Confirm that every cell executes in order and produces the expected output.</li>
# <li><b>Do NOT clear the output when submitting.</b> Submit the notebook with the output of each cell. The grader may use these values.</li>
# </ul>
# </div>

# %%
import os
import numpy as np
import seaborn as sns
import pandas as pd
import math
from scipy.optimize import fmin

# %%
# !git clone https://github.com/brendenlake/CMC2026.git
# %cd CMC2026/homeworks/homework-Categorization
# Out:
# Cloning into 'CMC2026'...
# remote: Enumerating objects: 89, done.
# remote: Counting objects: 100% (89/89), done.
# remote: Compressing objects: 100% (70/70), done.
# remote: Total 89 (delta 27), reused 67 (delta 13), pack-reused 0 (from 0)
# Receiving objects: 100% (89/89), 865.39 KiB | 4.18 MiB/s, done.
# Resolving deltas: 100% (27/27), done.
# /content/CMC2026/homeworks/homework-Categorization/CMC2026/homeworks/homework-Categorization

# %%
# !pip install -r requirements.txt
# Out:
# Requirement already satisfied: numpy>=1.24 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 14)) (2.1.3)
# Requirement already satisfied: pandas>=1.5 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 15)) (2.2.3)
# Requirement already satisfied: scipy>=1.9 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 16)) (1.16.3)
# Requirement already satisfied: matplotlib>=3.6 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 17)) (3.10.0)
# Requirement already satisfied: seaborn>=0.12 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 18)) (0.13.2)
# Requirement already satisfied: notebook>=6.5 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 19)) (6.5.7)
# Requirement already satisfied: ipykernel>=6.0 in /usr/local/lib/python3.13/dist-packages (from -r requirements.txt (line 20)) (6.17.1)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.5->-r requirements.txt (line 15)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.5->-r requirements.txt (line 15)) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.13/dist-packages (from pandas>=1.5->-r requirements.txt (line 15)) (2026.3)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.6->-r requirements.txt (line 17)) (1.3.3)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.6->-r requirements.txt (line 17)) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.6->-r requirements.txt (line 17)) (4.64.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.6->-r requirements.txt (line 17)) (1.5.1)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.6->-r requirements.txt (line 17)) (26.3)
# Requirement already satisfied: pillow>=8 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.6->-r requirements.txt (line 17)) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.13/dist-packages (from matplotlib>=3.6->-r requirements.txt (line 17)) (3.3.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (3.1.6)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (6.5.7)
# Requirement already satisfied: pyzmq>=17 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (26.2.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (25.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (5.9.1)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (7.4.9)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (5.11.1)
# Requirement already satisfied: nbconvert>=5 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (7.17.1)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (2.1.0)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (0.26.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.13/dist-packages (from notebook>=6.5->-r requirements.txt (line 19)) (1.3.3)
# Requirement already satisfied: debugpy>=1.0 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=6.0->-r requirements.txt (line 20)) (1.8.15)
# Requirement already satisfied: ipython>=7.23.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=6.0->-r requirements.txt (line 20)) (7.34.0)
# Requirement already satisfied: matplotlib-inline>=0.1 in /usr/local/lib/python3.13/dist-packages (from ipykernel>=6.0->-r requirements.txt (line 20)) (0.2.2)
# Requirement already satisfied: psutil in /usr/local/lib/python3.13/dist-packages (from ipykernel>=6.0->-r requirements.txt (line 20)) (5.9.5)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.13/dist-packages (from ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (80.10.2)
# Collecting jedi>=0.16 (from ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20))
#   Downloading jedi-0.20.0-py2.py3-none-any.whl.metadata (23 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.13/dist-packages (from ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.13/dist-packages (from ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (0.7.5)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.13/dist-packages (from ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (3.0.53)
# Requirement already satisfied: pygments in /usr/local/lib/python3.13/dist-packages (from ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (2.21.0)
# Requirement already satisfied: backcall in /usr/local/lib/python3.13/dist-packages (from ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (0.2.0)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.13/dist-packages (from ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (4.9.0)
# Requirement already satisfied: entrypoints in /usr/local/lib/python3.13/dist-packages (from jupyter-client<8,>=5.3.4->notebook>=6.5->-r requirements.txt (line 19)) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.13/dist-packages (from jupyter-core>=4.6.1->notebook>=6.5->-r requirements.txt (line 19)) (4.11.7)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.13/dist-packages (from nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (0.2.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (4.13.5)
# Requirement already satisfied: bleach!=5.0.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (6.4.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (0.7.1)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (0.3.0)
# Requirement already satisfied: markupsafe>=2.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (3.0.3)
# Requirement already satisfied: mistune<4,>=2.0.3 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (3.3.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (0.10.4)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.13/dist-packages (from nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=6.5->-r requirements.txt (line 19)) (2.22.2)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.13/dist-packages (from nbformat->notebook>=6.5->-r requirements.txt (line 19)) (4.26.0)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.13/dist-packages (from python-dateutil>=2.8.2->pandas>=1.5->-r requirements.txt (line 15)) (1.17.0)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.13/dist-packages (from terminado>=0.8.3->notebook>=6.5->-r requirements.txt (line 19)) (0.7.0)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.13/dist-packages (from argon2-cffi->notebook>=6.5->-r requirements.txt (line 19)) (26.1.0)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.13/dist-packages (from bleach!=5.0.0->bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (0.6.1)
# Requirement already satisfied: tinycss2>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from bleach[css]!=5.0.0->nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: parso<0.9.0,>=0.8.6 in /usr/local/lib/python3.13/dist-packages (from jedi>=0.16->ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (0.8.7)
# Requirement already satisfied: attrs>=22.2.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5->-r requirements.txt (line 19)) (26.1.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5->-r requirements.txt (line 19)) (2025.9.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5->-r requirements.txt (line 19)) (0.37.0)
# Requirement already satisfied: rpds-py>=0.25.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema>=2.6->nbformat->notebook>=6.5->-r requirements.txt (line 19)) (2026.6.3)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.13/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (2.20.0)
# Requirement already satisfied: wcwidth>=0.1.4 in /usr/local/lib/python3.13/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython>=7.23.1->ipykernel>=6.0->-r requirements.txt (line 20)) (0.8.3)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.13/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=6.5->-r requirements.txt (line 19)) (2.1.1)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (2.9.2)
# Requirement already satisfied: typing-extensions>=4.0.0 in /usr/local/lib/python3.13/dist-packages (from beautifulsoup4->nbconvert>=5->notebook>=6.5->-r requirements.txt (line 19)) (4.16.0)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.13/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=6.5->-r requirements.txt (line 19)) (3.0)
# Requirement already satisfied: anyio>=3.1.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (4.14.2)
# Requirement already satisfied: jupyter-events>=0.11.0 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (0.12.1)
# Requirement already satisfied: jupyter-server-terminals>=0.4.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (0.5.4)
# Requirement already satisfied: websocket-client>=1.7 in /usr/local/lib/python3.13/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (1.9.2)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.13/dist-packages (from anyio>=3.1.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (3.19)
# Requirement already satisfied: python-json-logger>=2.0.4 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (4.2.0)
# Requirement already satisfied: pyyaml>=5.3 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (6.0.3)
# Requirement already satisfied: rfc3339-validator in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /usr/local/lib/python3.13/dist-packages (from jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (0.1.1)
# Requirement already satisfied: fqdn in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (1.5.1)
# Requirement already satisfied: isoduration in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (3.1.1)
# Requirement already satisfied: rfc3987-syntax>=1.1.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (1.1.0)
# Requirement already satisfied: uri-template in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (1.3.0)
# Requirement already satisfied: webcolors>=24.6.0 in /usr/local/lib/python3.13/dist-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (25.10.0)
# Requirement already satisfied: lark>=1.2.2 in /usr/local/lib/python3.13/dist-packages (from rfc3987-syntax>=1.1.0->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (1.3.1)
# Requirement already satisfied: arrow>=0.15.0 in /usr/local/lib/python3.13/dist-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.11.0->jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook>=6.5->-r requirements.txt (line 19)) (1.4.0)
# Downloading jedi-0.20.0-py2.py3-none-any.whl (4.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.9/4.9 MB 34.0 MB/s eta 0:00:00
# Installing collected packages: jedi
# Successfully installed jedi-0.20.0

# %% [markdown]
# # Background and Theory

# %% [markdown]
# In this homework we explore the cognitive mechanisms that support unsupervised pattern categorization in humans.  In addition, we use this as an example of testing and comparing between models.

# %% [markdown]
# ## A simple (classic) unsupervised categorization experiment

# %% [markdown]
# Posner and Keele (1968) report a now classic categorization experiment with humans.  In the task participants viewed visual stimuli that are clouds of points (known as dot patterns) similar to a scatter plot of data on a graph.  An example of the stimuli is shown here:

# %% [markdown]
# <img src='https://github.com/brendenlake/CMC2026/blob/main/homeworks/homework-Categorization/images/singledotpattern.png?raw=1'>

# %% [markdown]
# **Experiment Design**
#
# Their experiment went like this, with some simplifications from their original procedure. The experiment was divided into a training and test phase.  During the training phase, for each subject a single random dot pattern was generated and considered to be the underlying "prototype" structure.  A prototype is like a common template or reference pattern.  The key is that participants never get to see the "prototype" pattern directly during training.  Instead they see what are known as "distortions" of the prototype.  A distortion of a pattern is made by adding random spatial noise to each point in a pattern to kind of "wiggle" the points away from their original position.
#
# For example, here is a random prototype (top) and a bunch of random distortions of the prototype made by adding or subtracting small random values from the `<x,y>` value of each point in the pattern.

# %% [markdown]
# <img src='https://github.com/brendenlake/CMC2026/blob/main/homeworks/homework-Categorization/images/distortions.png?raw=1'>

# %% [markdown]
# There are distortions that added more or less random noise.  For example, "high" distortions add a lot of randomness to the underlying template pattern whereas "low" distortions add only a little bit of noise.

# %% [markdown]
# **Training Phase**
#
# In the training phase of the experiment subjects view 10 training examples one at a time which are "high" distortions of a randomly generated prototype.  The instructions are that subjects should look at these patterns, and that they come from a single category similar to if you viewed a series of pictures of dogs they would all come from the category ``dog``.  Subjects were trying to figure out the pattern that related the different images to one another.
# Try it for yourself by looking at each of the "distortions" patterns above one by one and trying to detect the common structure.

# %% [markdown]
# **Test Phase**
#
# During the test phase, participants view a series of dot patterns one at a time and have to judge: **Does the given pattern come from the same general category or family you studied earlier or is it a new pattern that is different?**  This is an unsupervised categorization task because the subject has to abstract what the common structure is from the given patterns and then use that information to make classification decisions about new patterns.
#
# Unknown to participants the set of test items varied in a specific way with respect to the training patterns.  In particular, there were five particular types of patterns presented during test.
#
# - The first type were "old" patterns which were identical to those presented during the training phase.
# - The second type were "random" patterns which were from a completely new randomly generated prototype (thus had nothing to do with the items presented during training).
# - The third type were new "high distortions" of the underlying prototype that was used to create the study set.  These are thus similar to the "old" items but do not match exactly.
# - The fourth type were "low distortions" of the underlying prototype that was used to create the study set.  These are more similar to the prototype pattern than the "high" distortions are.
# - Finally the actual prototype used to generate the items during training was presented.  This pattern is interesting because the prototype pattern was never seen exactly during training.  However, people saw many high distortions of this item during training and given the instructions to detect what the common structure of the training patterns is, they may have learned something about this latent or hidden pattern.

# %% [markdown]
# **Typical Results**:
#
# This graph shows example results that are typical for an experiment like this:

# %%
df = pd.DataFrame({"Stimulus Type":['Prototype','Low','High','Random','Old'],"Probability of Endorsement":[0.91,0.76,0.5,0.27,0.79]})
ax = sns.barplot(x="Stimulus Type",y="Probability of Endorsement",data=df)
ax.set_ylim(0, 1.0);

# %% [markdown]
#  The height of the bars indicates the probability of endorsing a pattern as a member of the category during the test phase (high values mean that at test a subject is more likely to agree "yes this pattern fits with the one I learned").  Notice that the "old" items (the exact patterns studied during learning) are endorsed at a relatively high rate.  In contrast the "random" patterns (those coming from a completely different underlying pattern) are endorsed at a very low rate.  The low and high distortions are endorsed at intermediate rates (with the low distortions preferred).  Interestingly, the prototype pattern is endorsed most strongly even though it was never presented during the study period!  It is like during learning people figured out the underlying pattern that generated the stimuli!

# %% [markdown]
# ## Categorization: Memory for examples or abstractions?

# %% [markdown]
# The dot pattern experiments are interesting and have been replicated in various ways perhaps hundreds of times.  How do people make these judgments?  What information do people store during the study phase that would predict their performance in the test phase?  What rule do they use for combining information from memory in order to make these kinds of judgments?  We are going to build up a model of categorization in a few simple steps.

# %% [markdown]
# ## Step 1: How are dot patterns represented in the mind?

# %% [markdown]
# Our first question concerns how people represent the dot patterns and the distances between different dot patterns. Based on work from Smith and Minda (2002), let's assume the relationship between the physical distance of two dot patterns $i$ and $j$ (average distance between pairs on the screen) and the psychological distance between them $d_{ij}$ (how these distances are perceived) is as follows:

# %% [markdown]
# $\Large d_{ij} = \log(1 + \frac{\sum_m{\sqrt{(i_{mx}-j_{mx})^2 + (i_{my}-j_{my})^2}}}{9})$
#
# where $i_{mx}$ is the $x$ position of the $m$-th dot in pattern $i$ and $j_{mx}$ is the $x$ position for pattern $j$ (likewise for the $y$ position, $i_{my}$ and $j_{my}$). There are 9 dots total, so we divide by 9 to get the average. Because it can sometimes be ambiguous which dot aligns with which one in a pattern we choose the dots which are closest in the two patterns to compute this score.

# %% [markdown]
# ## Step 2: What is stored in memory?

# %% [markdown]
# The next consideration is what people actually store in memory during the training phase of the experiment.  There are of course many alternatives.  People could store an "average" of the points seen so far, or they could store each individual pattern that they have seen, or they could store nothing and try to figure it out at test, or they could store some verbal description of what the shapes "look like", or the shape of the outer edge of the dot-cloud (the "convex hull"), etc...

# %% [markdown]
# There are, however, two leading theories which have attracted considerable debate in the cognitive science literature: the prototype and exemplar theory.

# %% [markdown]
# ### Exemplar models

# %% [markdown]
# Exemplar models are a general class of psychological models related to nearest neighbor algorithms.  The most important feature of these models is the idea that people have what appears to be a nearly infinite memory for the past and as a result you can store all past experiences or examples in memory.  This seems crazy as we are forgetting things all the time but actually psychology is unclear about if we actually forget things or if we simply lose the ability to retrieve a memory (i.e., more like losing the pointer to the memory rather than decay).
#
# In machine learning, nearest neighbor classifiers use a distance function (like the one described above) to retrieve from memory the nearest labeled example and to predict the category membership based on the label for this item.  This nearest neighbor algorithm can be relaxed slightly to consider $k$-nearest neighbors.  According to this algorithm you find the $k$ neighbor examples (with $k>1$) to the current pattern and respond based on what the majority of these examples say.
#
# Now we can go a bit further and say that you compute the distance to all past examples but *weight* their vote according to how close they are.  So instead of picking the label of the closest or $k$-closest examples we compare the current pattern using a global match to all examples in the memory and weight their predictions based on similarity. This is an exemplar model... Pretty neat!

# %% [markdown]
# Ok, but how does this help us in the case of **unsupervised** categorization such as in the dot pattern case?  Here what we will assume is that we compute the similarity (written as $\eta_{ij}$ in the lecture slides) of the to-be-categorized item $i$ (the test item) to all the examples $j$ stored in memory and compare it to some criterion value.  If the sum of the similarities to all the examples is below this criterion then we assume the pattern is new and doesn't match what we learned.  If it is above the criterion we judge the item is a good example of the category.

# %% [markdown]
# We'll assume similarity takes the following form,
# <br><br>
# $\eta_{ij} = e^{-c \cdot d_{ij}}$.
# <br><br>
# Again, $d_{ij}$ is the psychological distance between pattern $i$ and pattern $j$ which is an example stored in memory during the study phase. This form has deeper relation to research on categorization that we'll discuss in class with regards to Shepard's universal law of generalization. $c$ is a free parameter that controls that weighting function and is often fitted to data.

# %% [markdown]
# In the (unsupervised) exemplar model we will consider that the probability of endorsing an item is going to be determined by the following equation:
# <br>
# $\Large P(A|i) = \frac{\sum_j e^{-c \cdot d_{ij}}}{\sum_j e^{-c \cdot d_{ij}} + k}$

# %% [markdown]
# where $P(A|i)$ is the probability of endorsing pattern $i$ as a member of the category seen during study.  $k$ is the criterion against which the summed similarity ($e^{-c \cdot d_{ij}}$) is being compared.  If $k$ is zero then you endorse the item as a member of the category all the time irrespective of the similarity and if $k$ gets large you become less and less likely to endorse the item (i.e., more likely to say no). You can think of it as the particular weighted nearest neighbor algorithm we think the mind uses. Note that there are no $\beta_A$ and $\beta_B$ bias parameters as in the lecture notes, which is used for making a two-way classification between A and B, which is not the scenario here.
#
# <img src="https://github.com/brendenlake/CMC2026/blob/main/homeworks/homework-Categorization/images/exemplarcompare.png?raw=1" width="400">

# %% [markdown]
# Together, this model implements the idea that very close matches ($d_{ij}=0$) are especially strong and things that are less similar count less.  You can think of it as the particular weighted nearest neighbor algorithm we think the mind uses.

# %% [markdown]
# ### Prototype models

# %% [markdown]
# A prototype model is different from an exemplar model because it assumes that instead of storing each of the training patterns in memory exactly, instead people store a single summary representation.  For example, people might store a mentally computed "average" pattern.  When you think about how you would perform the task you might think that you kind of compare the training patterns to one another and then compute some summary.
#
# <img src="https://github.com/brendenlake/CMC2026/blob/main/homeworks/homework-Categorization/images/prototypetheory.png?raw=1" width="500">
#
# In the case of the dot pattern stimuli one way to do this is to store a special trace in memory called the prototype which is the average of all the patterns seen so far (averaging the $<x,y>$ position of each point to find an average dot location).
#
# There are many different ways to operationalize a prototype model. According to the one we use here, the probability of endorsing a test item pattern as a member of the category that was studied during training is:

# %% [markdown]
# $\Large P(A|i) = \frac{e^{-c \cdot d_{ip}}}{e^{-c \cdot d_{ip}} + k}$

# %% [markdown]
# Note that nearly everything about this equation is the same except there is no longer a sum!  Instead we simply compute the distance between the test pattern and this special "prototype" pattern ($p$) which has been averaged from the training examples.
#
# <img src="https://github.com/brendenlake/CMC2026/blob/main/homeworks/homework-Categorization/images/prototypecomparison.png?raw=1" width="500">

# %% [markdown]
# ### Parameters

# %% [markdown]
# $k$ and $c$ are "free parameters" in both the exemplar and prototype model which are assumed to modulate or alter the core psychological processes.  These parameters might vary between subjects and as a function of condition.  Thus, in order to assess the ability of the model to account for the data we often "fit" these parameters to our data.

# %% [markdown]
# # Model Comparison

# %% [markdown]
# With these ideas in mind, in this homework you are going to compare the exemplar and prototype model to account for some data from an actual dot pattern categorization task collected with human subjects.  The goal is that by doing the homework you would develop some useful code that would let you more or less plug in a model that you might come across in your research, fit it to data, and verify that the fits are good, etc...

# %% [markdown]
# ## Reading in some data

# %% [markdown]
# The `data/` folder that comes with this homework contains data from 14 human subjects who participated in a dot pattern classification task.  The data describing each subject is in a text file (`.dat`) indexed by subject number (e.g., `1.dat`, `2.dat`, etc...).
#
# The organization of these files is as follows:

# %% [markdown]
# The first 44 lines of the file contain a description of the stimulus that the subject saw on a given trial including the x, y coordinate of each dot.  The first columns of these 44 lines is the number of the pattern (`1-44`).  The second column is the type of pattern using the following codes:
#
# - `1` = prototype
# - `2` = 10 "high distortions" of the prototype that were used as study patterns during learning
# - `3` = 10 new "high distortions" of the prototype presented during test
# - `4` = 4 "low distortions" of the prototype that were presented during test
# - `5` = 20 random items that come from different prototypes that were presented at test
#
# The next 18 values of each row are the coordinates of the dots (with the x, y coordinates in sequence).  So `[x1, y1, x2, y2, x3, y3, ...]`.

# %% [markdown]
# The following 40 lines of the file show the sequence of items presented during the study phase.  This is not all that important for our purposes, but basically the last column is which pattern was displayed (indexed from the patterns just described).  Each of 10 "high distortions" were presented four times each during study in a random order.

# %% [markdown]
# Finally the remaining lines of the file report the results of the test phase.  The first column is the subject number, the second column is the condition number, the next is the trial number in the experiment, the other columns worth mentioning are the last column (the pattern number from the beginning of the file), the second to last column (the type of stimulus it is according to the codes described above), and the reaction time in milliseconds.

# %% [markdown]
# In addition, participants in this experiment were assigned to one of two conditions: a recognition condition and a categorization condition.  These conditions differed only in the instructions given to participants at the start of the test phase.  In the recognition condition participants were told they would view a series of patterns and they should respond "yes" only if the pattern was **exactly** one they saw in the previous study phase.  In the categorization condition, participants were asked to respond "yes" only if the pattern belonged to the same general category or pattern that they observed in the training phase.

# %% [markdown]
# The following graph computes the probability of endorsement in the data set as a function of stimulus type and condition (Cat or Rec instructions).

# %%
################################
# getcurve
################################
def getcurve(filename):
    prototypes = []
    low = []
    old = []
    high = []
    random = []
    mydata = readfile(filename)
    cond = mydata[-1][1]
    for line in mydata:
        if line[4] == 2 and len(line) == 9:
            if line[7] == 1:
                prototypes.append(line[5])
            if line[7] == 2:
                old.append(line[5])
            if line[7] == 3:
                high.append(line[5])
            if line[7] == 4:
                low.append(line[5])
            if line[7] == 5:
                random.append(line[5])

    #print([len(prototypes), len(low), len(high), len(random), len(old)])
    # print(prototypes)
    # print(low)
    # print(high)
    # print(random)
    # print(old)
    return [np.average(prototypes), np.average(low), np.average(high), np.average(random), np.average(old), filename, cond]


def readfile(filename):
    results = []
    fp = open(filename, 'r')
    for line in fp.readlines():
        myline = list(map(int, line.split(' ')[:-1]))
        results.append(myline[:])
    fp.close()
    return results


def get_all_filenames(directoryname):
    files = filter(lambda x: x[-4:] == '.dat' and x[0] !=
                   '.', os.listdir(os.path.join(".", directoryname)))
    fn = map(lambda x: os.path.join(".", directoryname, x), files)
    # process each file and drop last 5 trials
    return list(fn)


def create_df(subjnum, cond, pattern):
    nobs = len(pattern)
    df = pd.DataFrame({"Subject": [subjnum]*nobs, "Condition": [cond]*nobs, "Stimulus Type": [
                      'Prototype', 'Low', 'High', 'Random', 'Old'], "Probability of Endorsement": pattern})
    return df


def get_human_results():
    allres = map(getcurve, get_all_filenames('data'))
    cat = []
    rec = []
    for patt in allres:
        if patt[-1] == 0:
            cat.append(create_df(patt[-2], 'cat', patt[:-2]))
        else:
            rec.append(create_df(patt[-2], 'rec', patt[:-2]))
    cat, rec = pd.concat(cat), pd.concat(rec)
    return pd.concat([cat, rec])

# %%
ax = sns.barplot(x="Stimulus Type", y="Probability of Endorsement", hue="Condition", data=get_human_results())
ax.set_ylim(0, 1.0);

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 1 (20 points) </h3><br>
# Using your own words explain the data pattern you see in the above figure.  What is different between the conditions and stimulus type?  Why do you suspect these patterns exist?  Your answer will need to consider the nature of the experiments, what is manipulated, and even your intuitive psychological theory about what might be going on.  Your response should take 3-4 sentences and appear in a cell below.  Is any feature of this data surprising to you?
# </div>

# %% [markdown]
# Starting with categorical vs recognition there is very clearly a difference in the probability of endorsement across the board. I'd sum it up generally with a sentiment that participants in the recognition group were generally much less confident in their absolute previous observation of figures and therefore were much less prone to endorse figures. They certainly did a great job not endorsing the random new creations, but on the whole weren't excellent in picking out previously seen figures, with only a success rate of around 60% (and also selecting loads of similar figures).
#
# On to the pattern of stimulus type. This is about what would be expected, as we were shown earlier in the assignment with the sample histogram. Participants did a great job identifying the prototype and small variations to it. This could be explained by saying they had calculated a prototype average in their heads from their training data, or that the prototype was just closer in psychological space compared to other samples.

# %% [markdown]
# ## Predictions for the exemplar model

# %% [markdown]
# The following cells set up the exemplar model using the equations described above.

# %%
################################
# unitdist:
# computes the euclidean distance between
# two dots
################################
def unitdist(x, y):
    x1 = np.array(x)
    y1 = np.array(y)
    return math.sqrt(sum(pow(x-y, 2.0)))


################################
# computeresponse
# computes the "activation" of each
# trace in memory
################################
def computeresponse(target, memory, c, k):
    res = []
    for mem in memory:
        res.append(
            math.log(1.0+np.average(list(map(lambda x, y: unitdist(x, y), target, mem)))))
    resp = [math.exp(-c*x) for x in res]
    pofr = sum(resp)/(sum(resp)+k)
    return pofr

# %%
################################
# exemplar model
# stores all 10 study items in memory
# and computes the probability of endorsement
# for each item type
################################


def exemplarmodel(filename, c, k):
    data = readfile(filename)
    cond = data[-1][1]
    memory = []
    for line in data:
        if len(line) == 20 and line[1] == 2:
            memory.append(np.resize(line[2:], (9, 2)))
    # print(memory)

    # prototype items
    proto = []
    for line in data:
        if len(line) == 20 and line[1] == 1:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            proto.append(pofr)
    # print(np.average(proto))

    # old items
    old = []
    for line in data:
        if len(line) == 20 and line[1] == 2:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            old.append(pofr)
    # print "p of r", old
    # print(np.average(old))

    # new high items
    newhigh = []
    for line in data:
        if len(line) == 20 and line[1] == 3:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            newhigh.append(pofr)
    # print(np.average(newhigh))

    # new low items
    newlow = []
    for line in data:
        if len(line) == 20 and line[1] == 4:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            newlow.append(pofr)
    # print(np.average(newlow))

    # random items
    random = []
    for line in data:
        if len(line) == 20 and line[1] == 5:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            random.append(pofr)
    # print(np.average(random))

    return [np.average(proto), np.average(newlow), np.average(newhigh), np.average(random), np.average(old), filename, cond]

# %%
def get_exemplar_results(c_cat, k_cat, c_rec, k_rec):
    allres = {fn: readfile(fn) for fn in get_all_filenames('data')}
    cat = []
    rec = []
    for filename in allres.keys():
        if allres[filename][-1][1] == 0:
            res = exemplarmodel(filename, c_cat, k_cat)
            cat.append(create_df(filename, 'cat', res[:-2]))
        else:
            res = exemplarmodel(filename, c_rec, k_rec)
            rec.append(create_df(filename, 'rec', res[:-2]))
    cat, rec = pd.concat(cat), pd.concat(rec)
    return pd.concat([cat, rec])

# %% [markdown]
# First let's replot the human results:

# %%
ax = sns.barplot(x="Stimulus Type", y="Probability of Endorsement", hue="Condition", data=get_human_results())
ax.set_ylim(0, 1.0);

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 2 (10 points) </h3><br>
# By hand adjust the setting of the model parameters to roughly fit the human data pattern shown above.
#
# 1. How close can you get?
#
# 2. What parameters did you find (report them) and your assessment of how well they fit.
#
# 3. Was it a good fit or are there systematic problems with the fit?  In addition, what are the parameter values and do they make sense in light of the equations described above?
#
# 4. When the parameters are the same for recognition and categorization instructions why do the bars look a little different?</div>

# %% [markdown]
# The cat one took a sec but I got pretty lucky with the rec version. Overall I got reasonably close. My method was to mostly focus on the prototype and random columns to align those. My parameters are:
#
# c_cat, k_cat, c_rec, k_rec = 2.1, 0.08, 2.0, 0.5
#
# While I successfully got Protoype and Random to fit quite well I struggled to fluctuate the Old group to match the humans as both cat and rec are too high by about 0.1. I also wasn't able to get the High to drop as dramatically. Perhaps these misfittings are a systemic problem, tho not too crazy.
#
# Though I tried playing with the $c$ value, it ended up coming back around to 2. $k$ had the largest effect to approximate the humans. This makes sense, as k would dictate the overall "willingness" to endorse something. If k were 0 or very small, you're quite liberal, whereas a high k makes you quite conservative. I think this difference in $k$ explains the difference between cat and rec very well.
#
# The differences in cat and rec off the bat exist because the cat and rec individuals were trained on different data. because there were only 14 data sets, so 7 per assignment, there is some variability in the training data available to the model.

# %% [markdown]
# The following cell lets you plot the model predictions for the exemplar model fitted to the stimuli that participants in this experiment actually viewed.  There is a $k$ and a $c$ parameter for both categorization and recognition.

# %%
c_cat, k_cat, c_rec, k_rec = 2.1, 0.08, 2.0, 0.5
ax = sns.barplot(x="Stimulus Type", y="Probability of Endorsement",
            hue="Condition", data=get_exemplar_results(c_cat, k_cat, c_rec, k_rec))
ax.set_ylim(0, 1.0);

# %% [markdown]
# ## Predictions for the prototype model

# %% [markdown]
# The following cells set up the prototype model using the equations described above.

# %%
################################
# prototype model
# stores an average of the study items in memory
# and computes the probability of endorsement
# for each item type
################################
def prototypemodel(filename, c, k):
    data = readfile(filename)
    cond = data[-1][1]
    # average all the old items in memory
    memory = [] # (10, 18) for 10 items of size 18
    for line in data:
        if len(line) == 20 and line[1] == 2:
            memory.append(line[2:])
    prototype = np.array(memory).mean(axis=0)         # (18,) average over the 10 patterns
    prototype = prototype.reshape(9, 2)               # (9, 2): 9 dots, averaged (x, y)
    memory = [prototype]

    # prototype items
    proto = []
    for line in data:
        if len(line) == 20 and line[1] == 1:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            proto.append(pofr)
    # print(np.average(proto))

    # old items
    old = []
    for line in data:
        if len(line) == 20 and line[1] == 2:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            old.append(pofr)
    # print "p of r", old
    # print(np.average(old))

    # new high items
    newhigh = []
    for line in data:
        if len(line) == 20 and line[1] == 3:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            newhigh.append(pofr)
    # print(np.average(newhigh))

    # new low items
    newlow = []
    for line in data:
        if len(line) == 20 and line[1] == 4:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            newlow.append(pofr)
    # print(np.average(newlow))

    # random items
    random = []
    for line in data:
        if len(line) == 20 and line[1] == 5:
            item = np.resize(line[2:], (9, 2))
            pofr = computeresponse(item, memory, c, k)
            random.append(pofr)
    # print(np.average(random))

    return [np.average(proto), np.average(newlow), np.average(newhigh), np.average(random), np.average(old), filename, cond]

# %%
def get_prototype_results(c_cat, k_cat, c_rec, k_rec):
    allres = {fn: readfile(fn) for fn in get_all_filenames('data')}
    cat = []
    rec = []
    for filename in allres.keys():
        if allres[filename][-1][1] == 0:
            res = prototypemodel(filename, c_cat, k_cat)
            cat.append(create_df(filename, 'cat', res[:-2]))
        else:
            res = prototypemodel(filename, c_rec, k_rec)
            rec.append(create_df(filename, 'rec', res[:-2]))
    cat, rec = pd.concat(cat), pd.concat(rec)
    return pd.concat([cat, rec])

# %% [markdown]
# Again lets replot the human results for easy reference.

# %%
ax = sns.barplot(x="Stimulus Type", y="Probability of Endorsement", hue="Condition", data=get_human_results())
ax.set_ylim(0, 1.0);

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 3 (10 points) </h3><br>
# By hand adjust the setting of the model parameters in the next cell to roughly fit the human data pattern shown above.
#
# 1. How close can you get?  What parameters did you find (report them) and your assessment of how well they fit.
#
# 2. Was it a good fit or are there systematic problems with the fit?  In addition, what are the parameter values and do they make sense in light of the equations described above?</div>

# %% [markdown]
# c_cat, k_cat, c_rec, k_rec = 1.4, 0.045, 1.4, 0.2
#
# I achieved a decent fit, though it was hard to get Prototype/Low around 0.9 while keeping High and Random much lower. For cat, the Old group fit much better. However, I struggled to get the rec Old up as high for humans while keeping the other measurements accurate.
#
# The systemic issue could be that Low will always be lower than Prototype, whereas the humans had some reversal of that (with larger error bars). But honestly mostly pretty reasonable. Again I think the parameters make sense here. You are just much more likely to accept anything with the category model, hence the much smaller $k$ value.

# %%
c_cat, k_cat, c_rec, k_rec = 1.4, 0.045, 1.4, 0.2
res=get_prototype_results(c_cat, k_cat, c_rec, k_rec)
ax = sns.barplot(x="Stimulus Type", y="Probability of Endorsement", hue="Condition", data=res)
ax.set_ylim(0, 1.0);

# %% [markdown]
# ## Fitting the models using RMSE

# %% [markdown]
# Next we would like to come up with a more quantitative way to assess the quality of the model fits. We need a "goodness of fit" measure, and we'll discuss a few different kinds throughout the semester. One of the most common measures of goodness of fit is the Root Mean Squared Error (RMSE).  This measure compares the value of each target $y$ to each prediction $\hat{y}$ (each a vector of $N$ dimensions) using the following equation:
# <br>
# $\Large RMSE = \sqrt{\frac{\sum_{b=1}^N (y_b - \hat{y}_b)^2}{N}}$
# </br>

# %% [markdown]
# Often the RMSE is computed between the AVERAGE prediction of the model and the AVERAGE estimates of the behavior to all the subjects in an experiment.  Using the code we developed above we can find the average endorsement curves for humans and both models like you see below. Note that this Python code uses the Pandas library. Here is a [short introduction](https://pandas.pydata.org/docs/user_guide/10min.html) and an explanation of the [.groupby](https://pandas.pydata.org/docs/user_guide/groupby.html) routine.

# %%
human_results=get_human_results()
exemplar_predictions = get_exemplar_results(c_cat, k_cat, c_rec, k_rec)
prototype_predictions = get_prototype_results(c_cat, k_cat, c_rec, k_rec)

# %%
avghuman=human_results.groupby(['Condition', 'Stimulus Type'],as_index=False)['Probability of Endorsement'].mean()
avghuman
# Out:
#   Condition Stimulus Type  Probability of Endorsement
# 0       cat          High                    0.700000
# 1       cat           Low                    0.928571
# 2       cat           Old                    0.785714
# 3       cat     Prototype                    0.892857
# 4       cat        Random                    0.264286
# 5       rec          High                    0.285714
# 6       rec           Low                    0.571429
# 7       rec           Old                    0.635714
# 8       rec     Prototype                    0.642857
# 9       rec        Random                    0.050000

# %%
avgexemplar=exemplar_predictions.groupby(['Condition', 'Stimulus Type'],as_index=False)['Probability of Endorsement'].mean()
avgexemplar
# Out:
#   Condition Stimulus Type  Probability of Endorsement
# 0       cat          High                    0.953854
# 1       cat           Low                    0.964117
# 2       cat           Old                    0.975789
# 3       cat     Prototype                    0.969811
# 4       cat        Random                    0.801119
# 5       rec          High                    0.836271
# 6       rec           Low                    0.872239
# 7       rec           Old                    0.907861
# 8       rec     Prototype                    0.892918
# 9       rec        Random                    0.469813

# %%
avgprototype=prototype_predictions.groupby(['Condition', 'Stimulus Type'], as_index=False)['Probability of Endorsement'].mean()
avgprototype
# Out:
#   Condition Stimulus Type  Probability of Endorsement
# 0       cat          High                    0.750604
# 1       cat           Low                    0.830644
# 2       cat           Old                    0.755548
# 3       cat     Prototype                    0.882440
# 4       cat        Random                    0.296707
# 5       rec          High                    0.413373
# 6       rec           Low                    0.537249
# 7       rec           Old                    0.450378
# 8       rec     Prototype                    0.644868
# 9       rec        Random                    0.084477

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 4 (20 points) </h3><br>
# First, write a function below called `rmse` that computes the RMSE between two `numpy` vectors.
# </div>

# %%
def rmse(human, model):
  return np.sqrt(np.mean((human-model)**2))

# %% [markdown]
# Write your code above.  This code will then be used in the provided functions below to evaluate the fit of the prototype and exemplar models.  The parameters to the model are provided as a list with `[c_cat, k_cat, c_rec, k_rec]` the implied order.

# %%
def fit_exemplar_model_rmse(params, human_results):
    [c_cat, k_cat, c_rec, k_rec] = params
    predictions = get_exemplar_results(c_cat, k_cat, c_rec, k_rec)
    avgpredict=predictions.groupby(['Condition', 'Stimulus Type'],as_index=False)['Probability of Endorsement'].mean()
    model_results = avgpredict['Probability of Endorsement'].values
    return rmse(human_results, model_results)

def fit_prototype_model_rmse(params, human_results):
    [c_cat, k_cat, c_rec, k_rec] = params
    predictions = get_prototype_results(c_cat, k_cat, c_rec, k_rec)
    avgpredict=predictions.groupby(['Condition', 'Stimulus Type'],as_index=False)['Probability of Endorsement'].mean()
    model_results = avgpredict['Probability of Endorsement'].values
    return rmse(human_results, model_results)

# %%
human_results=get_human_results()
avghuman=human_results.groupby(['Condition', 'Stimulus Type'],as_index=False)['Probability of Endorsement'].mean()
human_results = avghuman['Probability of Endorsement'].values
print(fit_exemplar_model_rmse([2.1, 0.09, 2.08, 0.55], human_results))
print(fit_prototype_model_rmse([1.4, 0.045, 1.35, 0.195], human_results))
# Out:
# 0.08169970051261319
# 0.08149058268946713

# %% [markdown]
# <div class="alert alert-success" role="alert">
# Next adjust the parameters by hand for both the exemplar and prototype models to find values that appear to minimize the RMSE.  Copy the code above for plotting the predictions of the models given your best fit parameters.   Which model do you think fits better according to this fit statistic?
# </div>

# %% [markdown]
# My errors are pretty close! Both just above 8.1%. However, I was able to get the prototype model to inch ahead by 0.02%. I'm not convinced I really have the lowest RMSE here though... But I didn't see too large of gains when changing from my original numbers earlier in the assignment.
#
# The biggest difference I'm seeing is in the exemplar model having a huge endorsement of Old subjects, which makes sense with the exemplar model. but I think it's a bit too confident compared to the human results there.

# %%
# exemplar

c_cat, k_cat, c_rec, k_rec = 2.1, 0.09, 2.08, 0.55
ax = sns.barplot(x="Stimulus Type", y="Probability of Endorsement",
            hue="Condition", data=get_exemplar_results(c_cat, k_cat, c_rec, k_rec))
ax.set_ylim(0, 1.0);

# %%
#human

ax = sns.barplot(x="Stimulus Type", y="Probability of Endorsement", hue="Condition", data=get_human_results())
ax.set_ylim(0, 1.0);

# %%
# prototype

c_cat, k_cat, c_rec, k_rec = 1.4, 0.045, 1.35, 0.195
res=get_prototype_results(c_cat, k_cat, c_rec, k_rec)
ax = sns.barplot(x="Stimulus Type", y="Probability of Endorsement", hue="Condition", data=res)
ax.set_ylim(0, 1.0);

# %% [markdown]
# <div class="alert alert-success" role="alert">
# <h3> Problem 5 (10 points) </h3><br>
# Read about the scipy `fmin` function.  Use fmin to algorithmically search for the best parameters for each model using the RMSE evaluation function described above. Make sure that you save the optimized values to the variables `rmse_exemplar` and `rmse_prototype`
#
# To unpack the outputs properly, write as:
# <br>param_opt_exemplar, rmse_exemplar, *_ = fmin(...your code here..., full_output=True)
# <br>param_opt_prototype, rmse_prototype, *_ = fmin(...your code here..., full_output=True)
# </div>

# %% [markdown]
# <div style="background-color: #eef2f6; color: #1f2933; border-left: 4px solid #7b8a97; padding: 12px 16px; border-radius: 4px;">
# Remidner
# <li><b>Do NOT clear the output when submitting.</b> Submit the notebook with the output of each cell. The grader may use these values.</li>
# </ul>
# </div>

# %%
### YOUR ANSWER HERE
### END ANSWER
exemplar_start = [2.1, 0.09, 2.08, 0.55]
param_opt_exemplar, rmse_exemplar, *_ = fmin(fit_exemplar_model_rmse, exemplar_start, args=(human_results,), full_output=True)

prototype_start = [1.4, 0.045, 1.35, 0.195]
param_opt_prototype, rmse_prototype, *_ = fmin(fit_prototype_model_rmse, prototype_start, args=(human_results,), full_output=True)

print('Optimal exemplar model:', param_opt_exemplar)
print('Optimal prototype model:', param_opt_prototype)

print('The RMSE for the exemplar model is: ', rmse_exemplar)
print('The RMSE for the prototype model is: ', rmse_prototype)
# Out:
# Optimization terminated successfully.
#          Current function value: 0.076819
#          Iterations: 107
#          Function evaluations: 186
# Optimization terminated successfully.
#          Current function value: 0.077796
#          Iterations: 80
#          Function evaluations: 144
# Optimal exemplar model: [1.73821198 0.17361148 1.92577153 0.66920704]
# Optimal prototype model: [1.62607979 0.0293933  1.62441416 0.14082471]
# The RMSE for the exemplar model is:  0.07681866356058187
# The RMSE for the prototype model is:  0.07779553417756684
